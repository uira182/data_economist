# %% [markdown]
# # Teste de instalação do data_economist
#
# Execute as 4 células abaixo na ordem para testar o pacote localmente antes de publicar no PyPI.
#
# **Requisito:** executar o notebook a partir da **raiz do projeto** (`c:\BAU\data_economist`) ou ajustar os caminhos.

# %%
import os
# Garantir que estamos na raiz do projeto (para python -m build e pip install dist/...)
if os.path.basename(os.getcwd()) == "tests":
    os.chdir("..")
print("Diretório de trabalho:", os.getcwd())
# Out:
# Diretório de trabalho: c:\BAU\data_economist

# %% [markdown]
# ## Etapa 1: Construir o pacote
#
# Gera a pasta `dist/` com o ficheiro `.whl` (e `.tar.gz`).

# %%
# !python -m build
# Out:
# running egg_info
# writing src\data_economist.egg-info\PKG-INFO
# writing dependency_links to src\data_economist.egg-info\dependency_links.txt
# writing requirements to src\data_economist.egg-info\requires.txt
# writing top-level names to src\data_economist.egg-info\top_level.txt
# reading manifest file 'src\data_economist.egg-info\SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'src\data_economist.egg-info\SOURCES.txt'
# running sdist
# running egg_info
# writing src\data_economist.egg-info\PKG-INFO
# writing dependency_links to src\data_economist.egg-info\dependency_links.txt
# writing requirements to src\data_economist.egg-info\requires.txt
# writing top-level names to src\data_economist.egg-info\top_level.txt
# reading manifest file 'src\data_economist.egg-info\SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'src\data_economist.egg-info\SOURCES.txt'
# running check
# creating data_economist-0.5.0
# ...

# %% [markdown]
# ## Etapa 2: Instalar a partir do .whl
#
# Instala o pacote como um utilizador que fez `pip install data-economist`.

# %%
# !pip install dist\data_economist-0.5.0-py3-none-any.whl --force-sreinstall
# Out:
# Processing .\dist\data_economist-0.5.0-py3-none-any.whl
# ...
#   Using cached pandas-3.0.1-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached numpy-2.4.2-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# ...
#   Using cached charset_normalizer-3.4.5-cp313-cp313-win_amd64.whl.metadata (39 kB)
# ...
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Using cached pandas-3.0.1-cp313-cp313-win_amd64.whl (9.7 MB)
# Using cached numpy-2.4.2-cp313-cp313-win_amd64.whl (12.3 MB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# ...

# %% [markdown]
# ## Etapa 3: Verificar instalação
#
# Importa o pacote e mostra a versão (e pode testar outras funções).

# %%
import data_economist

print("Versão:", data_economist.__version__)
print("Import OK.")
# Out:
# Versão: 0.4.0
# Import OK.

# %% [markdown]
# ## Etapa 4: Desinstalar (opcional)
#
# Remove o pacote instalado. Execute só se quiser deixar o ambiente limpo ou voltar a usar `pip install -e .`.

# %%
# !pip uninstall data-economist -y
# Out:
# WARNING: Skipping data-economist as it is not installed.
